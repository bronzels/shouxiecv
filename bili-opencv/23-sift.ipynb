# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

def cv_show(img):
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.show()
    
def cv2_show(img,name):
    cv2.imshow(name,img)
    cv2.waitKey()
    cv2.destroyAllWindows()

# %%
print(cv2.__version__)

img = cv2.imread('01_Picture/18_House.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# 将SIFT算法实例化出来
sift = cv2.xfeatures2d.SIFT_create()
# 把灰度图传进去，得到特征点，关键点
kp = sift.detect(gray, None)

img = cv2.drawKeypoints(gray, kp, img)
cv_show(img)
# Out:
# 4.10.0
# [ WARN:0@7.985] global shadow_sift.hpp:15 SIFT_create DEPRECATED: cv.xfeatures2d.SIFT_create() is deprecated due SIFT tranfer to the main repository. https://github.com/opencv/opencv/issues/16736

# %%
kp, des = sift.compute(gray, kp)
print(np.array(kp).shape)
print(np.array(kp)[0])
print(des.shape)
print(des[0])
# Out:
# (6809,)
# < cv2.KeyPoint 0x7fc2d08c4c00>
# (6809, 128)
# [  0.   0.   0.   0.   0.   0.   0.   0.  21.   8.   0.   0.   0.   0.
#    0.   0. 157.  31.   3.   1.   0.   0.   2.  63.  75.   7.  20.  35.
#   32.  74.  23.  66.   0.   0.   1.   3.   4.   1.   0.   0.  76.  15.
#   13.  27.   8.   1.   0.   2. 157. 112.  50.  31.   2.   0.   0.   9.
#   49.  42. 157. 157.  12.   4.   1.   5.   1.  13.   7.  12.  41.   5.
#    0.   0. 104.   8.   5.  19.  53.   5.   1.  21. 157.  55.  35.  90.
#   22.   0.   0.  17.   3.   6.  69. 157.  52.   0.   0.   0.   7.  33.
#   10.  10.  11.   0.   1.   6.  44.   9.   3.   7.  19.   5.  14.  26.
#   38.  28.  32.  92.  16.   2.   3.   4.   0.   0.   7.  92.  23.   0.
#    0.   0.]
