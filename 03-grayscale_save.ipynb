# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
img = cv2.imread("01_Picture/01_cat.jpg")
img.shape
# Out:
# (414, 500, 3)

# %%
img_grayscale = cv2.imread("01_Picture/01_cat.jpg", cv2.IMREAD_GRAYSCALE)
img_grayscale.shape
# Out:
# (414, 500)

# %%
print(type(img_grayscale))
print(img_grayscale.size)
print(img_grayscale.dtype)
print(img_grayscale.shape)
# Out:
# <class 'numpy.ndarray'>
# 207000
# uint8
# (414, 500)

# %%
plt.imshow(cv2.cvtColor(img_grayscale, cv2.COLOR_BGR2RGB))
plt.show()
